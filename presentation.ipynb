# %% [markdown]
# # Import wymaganych modułów

# %%
import numpy as np
import random
import json
import time
import my_math as my
import gen_value as gen
import matplotlib.pyplot as plt
import gen_value as gen
import plots as pl
import automated as am

# %% [markdown]
# # Eksperyment dla danych odwróconych

# %%
#Reversion file
#basic1=gen.reverse_List(0,2000,1)
##granica
basic1= gen.reverse_List(0,5906,2)
am.saveToFile(basic1,'reverse_list.txt')
pr_rev1=am.load('reverse_list.txt')
pr_rev2=am.load('reverse_list.txt')
pr_rev3=am.load('reverse_list.txt')
pr_rev4=am.load('reverse_list.txt')
pr_rev5=am.load('reverse_list.txt')

rev1=am.load('reverse_list.txt')
rev2=am.load('reverse_list.txt')
rev3=am.load('reverse_list.txt')
rev4=am.load('reverse_list.txt')
rev5=am.load('reverse_list.txt')
z0=am.run_all(rev1,rev2,rev3,rev4,rev5)
reversed_time=am.conversion(z0)
# Out:
# [2.2383689880371094, 0.4740111827850342, 1.6801245212554932, 0.42995667457580566, 0.7150263786315918]

# %%
print("\nReversed:\n")
print(am.print_time("bubble",pr_rev1))
print(am.print_time("selection",pr_rev2))
print(am.print_time("insertion",pr_rev3))
print(am.print_time("quick",pr_rev4))
print(am.print_time("iteration",pr_rev5))
# Out:
# Reversed:
#
# BubbleSort = 2.206620 s
# Selection = 0.478369 s
# Insertion = 1.685349 s
# Quick = 0.435329 s
# Iteration Qick = 0.734284 s

# %%
pl.reverse_plot(reversed_time)

# %% [markdown]
# # Eksperyment dla danych potasowanych i odwróconych

# %%
#shuffling= gen.rev_And_Shuff(0,1001,1,2000)
shuffling= gen.rev_And_Shuff(0,2930,1,4000)
am.saveToFile(shuffling,'Rev_and_Shuff.txt')
pr_fac1=am.load('Rev_and_Shuff.txt')
pr_fac2=am.load('Rev_and_Shuff.txt')
pr_fac3=am.load('Rev_and_Shuff.txt')
pr_fac4=am.load('Rev_and_Shuff.txt')
pr_fac5=am.load('Rev_and_Shuff.txt')
fac1=am.load('Rev_and_Shuff.txt')
fac2=am.load('Rev_and_Shuff.txt')
fac3=am.load('Rev_and_Shuff.txt')
fac4=am.load('Rev_and_Shuff.txt')
fac5=am.load('Rev_and_Shuff.txt')
######print(fac4)
z1=am.run_all(fac1,fac2,fac3,fac4,fac5)
rev_and_shuff=am.conversion(z1)
# Out:
# [4.33355450630188, 0.9649999141693115, 3.1146552562713623, 0.8293435573577881, 0.7272882461547852]

# %%
print("\nRev and shuff:\n")
print(am.print_time("bubble",pr_fac1))
print(am.print_time("selection",pr_fac2))
print(am.print_time("insertion",pr_fac3))
print(am.print_time("quick",pr_fac4))
print(am.print_time("iteration",pr_fac5))
# Out:
# Rev and shuff:
#
# BubbleSort = 4.051266 s
# Selection = 0.872006 s
# Insertion = 3.056563 s
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-19-6540de96f3c1> in <module>
#       3 print(am.print_time("selection",pr_fac2))
#       4 print(am.print_time("insertion",pr_fac3))
# ----> 5 print(am.print_time("quick",pr_fac4))
#       6 print(am.print_time("iteration",pr_fac5))
#
# c:\Users\Szymon\Desktop\OBRONA\kod\automated.py in print_time(name, data)
#      34     elif (name=="quick"):
#      35         s= time.time()
# ---> 36         my.quick_sort(data)
#      37         e = time.time()
#      38         score=e-s
#
# c:\Users\Szymon\Desktop\OBRONA\kod\my_math.py in quick_sort(list)
#      52                items_lower.append(item)
#      53
# ---> 54       return quick_sort(items_lower)+[pivot]+quick_sort(items_greater)
#      55
# ...

# %%
pl.rev_and_shuff_plot(rev_and_shuff)

# %% [markdown]
# # Eksperyment dla danych potasowanych

# %%
#randomly schuffling  OK!!!!!!!!!!
lm1=gen.random_shuffling(0,20000,1)
am.saveToFile(lm1,'random_schuffle.txt')
pr_ran1=am.load('random_schuffle.txt')
pr_ran2=am.load('random_schuffle.txt')
pr_ran3=am.load('random_schuffle.txt')
pr_ran4=am.load('random_schuffle.txt')
pr_ran5=am.load('random_schuffle.txt')
ran1=am.load('random_schuffle.txt')
ran2=am.load('random_schuffle.txt')
ran3=am.load('random_schuffle.txt')
ran4=am.load('random_schuffle.txt') #qick
ran5=am.load('random_schuffle.txt') #iteration

z2=am.run_all(ran1,ran2,ran3,ran4,ran5)
random_time=am.conversion(z2)
# Out:
# [20.14399814605713, 4.852003335952759, 10.340996742248535, 0.021001815795898438, 0.03500008583068848]

# %%
print("\nRandom schuffle-python:\n")
print(am.print_time("bubble",pr_ran1))
print(am.print_time("selection",pr_ran2))
print(am.print_time("insertion",pr_ran3))
print(am.print_time("quick",pr_ran4))
print(am.print_time("iteration",pr_ran5))
# Out:
# Random schuffle-python:
#
# BubbleSort = 20.133999 s
# Selection = 5.091002 s
# Insertion = 10.489997 s
# Quick = 0.021003 s
# Iteration Qick = 0.035999 s

# %%
pl.shuffle_python_plot(random_time)

# %% [markdown]
# # Eksperyment dla danych losowych

# %%
#tottaly randomly elements in list OK!
##lm2=gen.random_value(5000,0,1000) ### ilość liczb, zakres liczb od- do
lm2=gen.random_value(2000,0,1000)
am.saveToFile(lm2,'suprised_random.txt')
pr_rep1=am.load('suprised_random.txt')
pr_rep2=am.load('suprised_random.txt')
pr_rep3=am.load('suprised_random.txt')
pr_rep4=am.load('suprised_random.txt')
pr_rep5=am.load('suprised_random.txt')
rep1=am.load('suprised_random.txt')
rep2=am.load('suprised_random.txt')
rep3=am.load('suprised_random.txt')
rep4=am.load('suprised_random.txt')
rep5=am.load('suprised_random.txt')
z3=am.run_all(rep1,rep2,rep3,rep4,rep5)
random_reps_time=am.conversion(z3)
# Out:
# [4.907999038696289, 1.1849985122680664, 2.593001127243042, 0.010001897811889648, 0.020998477935791016]

# %%
print("\nReverse and shuffle with reps:\n")
print(am.print_time("bubble",pr_rep1))
print(am.print_time("selection",pr_rep2))
print(am.print_time("insertion",pr_rep3))
print(am.print_time("quick",pr_rep4))
print(am.print_time("iteration",pr_rep5))
# Out:
# Reverse and shuffle with reps:
#
# BubbleSort = 5.379001 s
# Selection = 1.295001 s
# Insertion = 2.609998 s
# Quick = 0.012003 s
# Iteration Qick = 0.020998 s

# %%
pl.random_reps_plot(random_reps_time)

# %%
diff_data= ['Reversed','FactorSchuffle','RandomSchuffle','Value reps']
xnew=np.arange(0,8,2)
Iqick= [reversed_time[4],rev_and_shuff[4],random_time[4],random_reps_time[4]]
qick=[reversed_time[3],rev_and_shuff[3],random_time[3],random_reps_time[3]]
plt.xticks(xnew,diff_data)
plt.ylabel("czas w milisekundach")
plt.title("Qick sort vs Iteration Qick sort")
plt.bar(xnew+0.25,Iqick,width=0.5,label="Iteration Qick Sort",color = "green")
plt.bar(xnew-0.25,qick,width=0.5,label="Qick Sort",color = "blue")
plt.legend()

# %%
diff_data= ['Reversed','FactorSchuffle','RandomSchuffle','Value reps']
xnew=np.arange(0,8,2)
sel= [reversed_time[1],rev_and_shuff[1],random_time[1],random_reps_time[1]]
ins=[reversed_time[2],rev_and_shuff[2],random_time[2],random_reps_time[2]]
plt.xticks(xnew,diff_data)
plt.ylabel("czas w milisekundach")
plt.title("Selection sort vs Insertion sort")
plt.bar(xnew+0.25,sel,width=0.5,label="Selection sort",color = "red")
plt.bar(xnew-0.25,ins,width=0.5,label="Insertion sort",color = "gray")
plt.legend()

# %% [markdown]
# # Podsumowanie

# %%
pl.reverse_plot(reversed_time)

# %%
pl.shuffle_python_plot(random_time)

# %%
pl.random_reps_plot(random_reps_time)

# %%
pl.rev_and_shuff_plot(rev_and_shuff)
